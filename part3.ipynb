# %%
#creating Dataframe from list of list

# %%
import pandas as pd

# %%
list_data = [["C1", 5, "Jakarta"], ["C2", 7, "Bogor"], ["C3", 4, "Tanggerang"], ["C4", 2, "Jakarta"]]

# %%
df = pd.DataFrame(list_data, columns = ["customer_id", "bought", "city"])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.DataFrame(list_data, columns = ["customer_id", "bought", "city"])
#       2 df
#
# NameError: name 'pd' is not defined

# %%
#creating Dataframe Numpy Array

# %%
import numpy as np

# %%
numpy_data = np.array(list_data)
numpy_data
# Out:
# array([['C1', '5', 'Jakarta'],
#        ['C2', '7', 'Bogor'],
#        ['C3', '4', 'Tanggerang'],
#        ['C4', '2', 'Jakarta']], dtype='<U21')

# %%
df = pd.DataFrame(numpy_data, columns = ["customer_id", "bought", "city"])
df
# Out:
#   customer_id bought        city
# 0          C1      5     Jakarta
# 1          C2      7       Bogor
# 2          C3      4  Tanggerang
# 3          C4      2     Jakarta

# %%
dictionary_data = {"customer_id" : ["C1", "C2", "C3"],
                  "bought" : [5, 7, 2],
                   "city" : ["Jakarta", "Tangerang", "Bogor"]
                  }
dictionary_data
# Out:
# {'customer_id': ['C1', 'C2', 'C3'],
#  'bought': [5, 7, 2],
#  'city': ['Jakarta', 'Tangerang', 'Bogor']}

# %%
df = pd.DataFrame(dictionary_data)
df
# Out:
#   customer_id  bought       city
# 0          C1       5    Jakarta
# 1          C2       7  Tangerang
# 2          C3       2      Bogor

# %%
#Saving Dataframe

# %%
df
# Out:
#   customer_id  bought       city
# 0          C1       5    Jakarta
# 1          C2       7  Tangerang
# 2          C3       2      Bogor

# %%
df.to_csv("customer_info.csv", index = False)

# %%
df.to_excel("customer_info.xlsx", index = False)

# %%
#Load Dataframe

# %%
df = pd.read_csv("customer_info.csv")
df
# Out:
#   customer_id  bought       city
# 0          C1       5    Jakarta
# 1          C2       7  Tangerang
# 2          C3       2      Bogor

# %%
df = pd.read_excel("customer_info.xlsx")
df
# Out:
#   customer_id  bought       city
# 0          C1       5    Jakarta
# 1          C2       7  Tangerang
# 2          C3       2      Bogor

# %%
#Basic operation

# %%
df = pd.DataFrame({"customer_id" : ["C1", "C2", "C3", "C4", "C5", "C6", "C7", "C8", "C9", "C10"],
                  "bought" : [5, 7, 2, 4, 5, 2, 5, 6, 1, 2],
                   "city" : ["Jakarta", "Tangerang", "Bogor", "Jakarta", "Tangerang", "Bogor", "Jakarta", "Tangerang", "Bogor", "Bogor"]
                  })

# %%
#Summary Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  10 non-null     object
#  1   bought       10 non-null     int64
#  2   city         10 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 372.0+ bytes

# %%
df
# Out:
#   customer_id  bought       city
# 0          C1       5    Jakarta
# 1          C2       7  Tangerang
# 2          C3       2      Bogor
# 3          C4       4    Jakarta
# 4          C5       5  Tangerang
# 5          C6       2      Bogor
# 6          C7       5    Jakarta
# 7          C8       6  Tangerang
# 8          C9       1      Bogor
# 9         C10       2      Bogor

# %%
df.describe()
# Out:
#           bought
# count  10.000000
# mean    3.900000
# std     2.024846
# min     1.000000
# 25%     2.000000
# 50%     4.500000
# 75%     5.000000
# max     7.000000

# %%
#columns name

# %%
df
# Out:
#   customer_id  bought       city
# 0          C1       5    Jakarta
# 1          C2       7  Tangerang
# 2          C3       2      Bogor
# 3          C4       4    Jakarta
# 4          C5       5  Tangerang
# 5          C6       2      Bogor
# 6          C7       5    Jakarta
# 7          C8       6  Tangerang
# 8          C9       1      Bogor
# 9         C10       2      Bogor

# %%
df.columns
# Out:
# Index(['customer_id', 'bought', 'city'], dtype='object')

# %%
list(df.columns)
# Out:
# ['customer_id', 'bought', 'city']

# %%
for i in list(df.columns):
    print(i)
# Out:
# customer_id
# bought
# city

# %%
#daraframe lenght

# %%
df
# Out:
#   customer_id  bought       city
# 0          C1       5    Jakarta
# 1          C2       7  Tangerang
# 2          C3       2      Bogor
# 3          C4       4    Jakarta
# 4          C5       5  Tangerang
# 5          C6       2      Bogor
# 6          C7       5    Jakarta
# 7          C8       6  Tangerang
# 8          C9       1      Bogor
# 9         C10       2      Bogor

# %%
df.shape
# Out:
# (10, 3)

# %%
#banyaknya baris
df.shape[0]
# Out:
# 10

# %%
#banyaknya column
df.shape[1]
# Out:
# 3

# %%
#values of a particular column

# %%
df
# Out:
#   customer_id  bought       city
# 0          C1       5    Jakarta
# 1          C2       7  Tangerang
# 2          C3       2      Bogor
# 3          C4       4    Jakarta
# 4          C5       5  Tangerang
# 5          C6       2      Bogor
# 6          C7       5    Jakarta
# 7          C8       6  Tangerang
# 8          C9       1      Bogor
# 9         C10       2      Bogor

# %%
df["customer_id"]
# Out:
# 0     C1
# 1     C2
# 2     C3
# 3     C4
# 4     C5
# 5     C6
# 6     C7
# 7     C8
# 8     C9
# 9    C10
# Name: customer_id, dtype: object

# %%
df["bought"]
# Out:
# 0    5
# 1    7
# 2    2
# 3    4
# 4    5
# 5    2
# 6    5
# 7    6
# 8    1
# 9    2
# Name: bought, dtype: int64

# %%
df["city"]
# Out:
# 0      Jakarta
# 1    Tangerang
# 2        Bogor
# 3      Jakarta
# 4    Tangerang
# 5        Bogor
# 6      Jakarta
# 7    Tangerang
# 8        Bogor
# 9        Bogor
# Name: city, dtype: object

# %%
#values of several columns

# %%
df[["customer_id", "bought"]]
# Out:
#   customer_id  bought
# 0          C1       5
# 1          C2       7
# 2          C3       2
# 3          C4       4
# 4          C5       5
# 5          C6       2
# 6          C7       5
# 7          C8       6
# 8          C9       1
# 9         C10       2

# %%
df[["customer_id", "city"]]
# Out:
#   customer_id       city
# 0          C1    Jakarta
# 1          C2  Tangerang
# 2          C3      Bogor
# 3          C4    Jakarta
# 4          C5  Tangerang
# 5          C6      Bogor
# 6          C7    Jakarta
# 7          C8  Tangerang
# 8          C9      Bogor
# 9         C10      Bogor

# %%
#first N rows

# %%
df
# Out:
#   customer_id  bought       city
# 0          C1       5    Jakarta
# 1          C2       7  Tangerang
# 2          C3       2      Bogor
# 3          C4       4    Jakarta
# 4          C5       5  Tangerang
# 5          C6       2      Bogor
# 6          C7       5    Jakarta
# 7          C8       6  Tangerang
# 8          C9       1      Bogor
# 9         C10       2      Bogor

# %%
df.head()
# Out:
#   customer_id  bought       city
# 0          C1       5    Jakarta
# 1          C2       7  Tangerang
# 2          C3       2      Bogor
# 3          C4       4    Jakarta
# 4          C5       5  Tangerang

# %%
df.head(2)
# Out:
#   customer_id  bought       city
# 0          C1       5    Jakarta
# 1          C2       7  Tangerang

# %%
df.head(10)
# Out:
#   customer_id  bought       city
# 0          C1       5    Jakarta
# 1          C2       7  Tangerang
# 2          C3       2      Bogor
# 3          C4       4    Jakarta
# 4          C5       5  Tangerang
# 5          C6       2      Bogor
# 6          C7       5    Jakarta
# 7          C8       6  Tangerang
# 8          C9       1      Bogor
# 9         C10       2      Bogor

# %%
#last n rows

# %%
df.tail()
# Out:
#   customer_id  bought       city
# 5          C6       2      Bogor
# 6          C7       5    Jakarta
# 7          C8       6  Tangerang
# 8          C9       1      Bogor
# 9         C10       2      Bogor

# %%
df.tail(2)
# Out:
#   customer_id  bought   city
# 8          C9       1  Bogor
# 9         C10       2  Bogor

# %%
#randow n rows

# %%
df.sample()
# Out:
#   customer_id  bought       city
# 1          C2       7  Tangerang

# %%
df.sample(4)
# Out:
#   customer_id  bought       city
# 7          C8       6  Tangerang
# 1          C2       7  Tangerang
# 8          C9       1      Bogor
# 6          C7       5    Jakarta

# %%
#sorting data

# %%
df
# Out:
#   customer_id  bought       city
# 0          C1       5    Jakarta
# 1          C2       7  Tangerang
# 2          C3       2      Bogor
# 3          C4       4    Jakarta
# 4          C5       5  Tangerang
# 5          C6       2      Bogor
# 6          C7       5    Jakarta
# 7          C8       6  Tangerang
# 8          C9       1      Bogor
# 9         C10       2      Bogor

# %%
df.sort_values(by = "bought", ascending = False)
# Out:
#   customer_id  bought       city
# 1          C2       7  Tangerang
# 7          C8       6  Tangerang
# 0          C1       5    Jakarta
# 4          C5       5  Tangerang
# 6          C7       5    Jakarta
# 3          C4       4    Jakarta
# 2          C3       2      Bogor
# 5          C6       2      Bogor
# 9         C10       2      Bogor
# 8          C9       1      Bogor

# %%
df.sort_values(by = "bought")
# Out:
#   customer_id  bought       city
# 8          C9       1      Bogor
# 2          C3       2      Bogor
# 5          C6       2      Bogor
# 9         C10       2      Bogor
# 3          C4       4    Jakarta
# 0          C1       5    Jakarta
# 4          C5       5  Tangerang
# 6          C7       5    Jakarta
# 7          C8       6  Tangerang
# 1          C2       7  Tangerang

# %%
df.sort_values(by = ["bought", "customer_id"], ascending = False)
# Out:
#   customer_id  bought       city
# 1          C2       7  Tangerang
# 7          C8       6  Tangerang
# 6          C7       5    Jakarta
# 4          C5       5  Tangerang
# 0          C1       5    Jakarta
# 3          C4       4    Jakarta
# 5          C6       2      Bogor
# 2          C3       2      Bogor
# 9         C10       2      Bogor
# 8          C9       1      Bogor

# %%
df.sort_values(by = ["bought", "customer_id"], ascending = False).reset_index(drop = True)
# Out:
#   customer_id  bought       city
# 0          C2       7  Tangerang
# 1          C8       6  Tangerang
# 2          C7       5    Jakarta
# 3          C5       5  Tangerang
# 4          C1       5    Jakarta
# 5          C4       4    Jakarta
# 6          C6       2      Bogor
# 7          C3       2      Bogor
# 8         C10       2      Bogor
# 9          C9       1      Bogor

# %%
#rename columns

# %%
df
# Out:
#   customer_id  bought       city
# 0          C1       5    Jakarta
# 1          C2       7  Tangerang
# 2          C3       2      Bogor
# 3          C4       4    Jakarta
# 4          C5       5  Tangerang
# 5          C6       2      Bogor
# 6          C7       5    Jakarta
# 7          C8       6  Tangerang
# 8          C9       1      Bogor
# 9         C10       2      Bogor

# %%
df.rename(columns = {"customer_id": "cust_id", "bought": "num_of_item"})
# Out:
#   cust_id  num_of_item       city
# 0      C1            5    Jakarta
# 1      C2            7  Tangerang
# 2      C3            2      Bogor
# 3      C4            4    Jakarta
# 4      C5            5  Tangerang
# 5      C6            2      Bogor
# 6      C7            5    Jakarta
# 7      C8            6  Tangerang
# 8      C9            1      Bogor
# 9     C10            2      Bogor

# %%
df.columns = ["cust_id", "num_of_item", "user_city"]

# %%
df
# Out:
#   cust_id  num_of_item  user_city
# 0      C1            5    Jakarta
# 1      C2            7  Tangerang
# 2      C3            2      Bogor
# 3      C4            4    Jakarta
# 4      C5            5  Tangerang
# 5      C6            2      Bogor
# 6      C7            5    Jakarta
# 7      C8            6  Tangerang
# 8      C9            1      Bogor
# 9     C10            2      Bogor

# %%
#change data type

# %%
df
# Out:
#   cust_id  num_of_item  user_city
# 0      C1            5    Jakarta
# 1      C2            7  Tangerang
# 2      C3            2      Bogor
# 3      C4            4    Jakarta
# 4      C5            5  Tangerang
# 5      C6            2      Bogor
# 6      C7            5    Jakarta
# 7      C8            6  Tangerang
# 8      C9            1      Bogor
# 9     C10            2      Bogor

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cust_id      10 non-null     object
#  1   num_of_item  10 non-null     int64
#  2   user_city    10 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 372.0+ bytes

# %%
df["num_of_item"] = df["num_of_item"].astype("float64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cust_id      10 non-null     object
#  1   num_of_item  10 non-null     float64
#  2   user_city    10 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 372.0+ bytes

# %%
df
# Out:
#   cust_id  num_of_item  user_city
# 0      C1          5.0    Jakarta
# 1      C2          7.0  Tangerang
# 2      C3          2.0      Bogor
# 3      C4          4.0    Jakarta
# 4      C5          5.0  Tangerang
# 5      C6          2.0      Bogor
# 6      C7          5.0    Jakarta
# 7      C8          6.0  Tangerang
# 8      C9          1.0      Bogor
# 9     C10          2.0      Bogor

# %%
df["num_of_item"] = df["num_of_item"].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cust_id      10 non-null     object
#  1   num_of_item  10 non-null     int64
#  2   user_city    10 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 372.0+ bytes

# %%
df
# Out:
#   cust_id  num_of_item  user_city
# 0      C1            5    Jakarta
# 1      C2            7  Tangerang
# 2      C3            2      Bogor
# 3      C4            4    Jakarta
# 4      C5            5  Tangerang
# 5      C6            2      Bogor
# 6      C7            5    Jakarta
# 7      C8            6  Tangerang
# 8      C9            1      Bogor
# 9     C10            2      Bogor

# %%
df["num_of_item"] = df["num_of_item"].astype("object")

# %%
df
# Out:
#   cust_id num_of_item  user_city
# 0      C1           5    Jakarta
# 1      C2           7  Tangerang
# 2      C3           2      Bogor
# 3      C4           4    Jakarta
# 4      C5           5  Tangerang
# 5      C6           2      Bogor
# 6      C7           5    Jakarta
# 7      C8           6  Tangerang
# 8      C9           1      Bogor
# 9     C10           2      Bogor

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cust_id      10 non-null     object
#  1   num_of_item  10 non-null     object
#  2   user_city    10 non-null     object
# dtypes: object(3)
# memory usage: 372.0+ bytes

# %%
#data filtering

# %%
df = pd.DataFrame({"customer_id" : ["C1", "C2", "C3", "C4", "C5", "C6", "C7", "C8", "C9", "C10"],
                  "item_bought" : [5, 7, 2, 4, 5, 2, 5, 6, 1, 2],
                   "city" : ["Jakarta", "Arab", "Bogor", "Jakarta", "Malysia", "Bogor", "Jakarta", "Jawa", "Bogor", "Bogor"]
                  })
df
# Out:
#   customer_id  item_bought       city
# 0          C1            5    Jakarta
# 1          C2            7  Tangerang
# 2          C3            2      Bogor
# 3          C4            4    Jakarta
# 4          C5            5  Tangerang
# 5          C6            2      Bogor
# 6          C7            5    Jakarta
# 7          C8            6       Jawa
# 8          C9            1      Bogor
# 9         C10            2      Bogor

# %%
#loc

# %%
#single value

# %%
df.loc[0, "customer_id"]
# Out:
# 'C1'

# %%
df.loc[5, "city"]
# Out:
# 'Bogor'

# %%
df.loc[2, "item_bought"]
# Out:
# 2

# %%
#range of rows/columns

# %%
df.loc[0:4, "customer_id"]
# Out:
# 0    C1
# 1    C2
# 2    C3
# 3    C4
# 4    C5
# Name: customer_id, dtype: object

# %%
df.loc[0:4, ["customer_id", "city"]]
# Out:
#   customer_id       city
# 0          C1    Jakarta
# 1          C2  Tangerang
# 2          C3      Bogor
# 3          C4    Jakarta
# 4          C5  Tangerang

# %%
df.loc[2, ["customer_id", "city"]]
# Out:
# customer_id       C3
# city           Bogor
# Name: 2, dtype: object

# %%
#iloc

# %%
df
# Out:
#   customer_id  item_bought       city
# 0          C1            5    Jakarta
# 1          C2            7  Tangerang
# 2          C3            2      Bogor
# 3          C4            4    Jakarta
# 4          C5            5  Tangerang
# 5          C6            2      Bogor
# 6          C7            5    Jakarta
# 7          C8            6  Tangerang
# 8          C9            1      Bogor
# 9         C10            2      Bogor

# %%
#single value

# %%
df.iloc[0, 0]
# Out:
# 'C1'

# %%
df.iloc[2, 2]
# Out:
# 'Bogor'

# %%
df.iloc[5, 1]
# Out:
# 2

# %%
 #range of values

# %%
df.iloc[0:2, 0]
# Out:
# 0    C1
# 1    C2
# Name: customer_id, dtype: object

# %%
df.iloc[0:2, 0:3]
# Out:
#   customer_id  item_bought       city
# 0          C1            5    Jakarta
# 1          C2            7  Tangerang

# %%
#filtering dataframe with criteria

# %%
#object

# %%
df
# Out:
#   customer_id  item_bought       city
# 0          C1            5    Jakarta
# 1          C2            7  Tangerang
# 2          C3            2      Bogor
# 3          C4            4    Jakarta
# 4          C5            5  Tangerang
# 5          C6            2      Bogor
# 6          C7            5    Jakarta
# 7          C8            6  Tangerang
# 8          C9            1      Bogor
# 9         C10            2      Bogor

# %%
df[(df["city"] == "Jakarta")]
# Out:
#   customer_id  item_bought     city
# 0          C1            5  Jakarta
# 3          C4            4  Jakarta
# 6          C7            5  Jakarta

# %%
df[(df["customer_id"] == "C8")]
# Out:
#   customer_id  item_bought       city
# 7          C8            6  Tangerang

# %%
#numeric

# %%
df
# Out:
#   customer_id  item_bought       city
# 0          C1            5    Jakarta
# 1          C2            7  Tangerang
# 2          C3            2      Bogor
# 3          C4            4    Jakarta
# 4          C5            5  Tangerang
# 5          C6            2      Bogor
# 6          C7            5    Jakarta
# 7          C8            6  Tangerang
# 8          C9            1      Bogor
# 9         C10            2      Bogor

# %%
df[(df["item_bought"] >= 5)]
# Out:
#   customer_id  item_bought       city
# 0          C1            5    Jakarta
# 1          C2            7  Tangerang
# 4          C5            5  Tangerang
# 6          C7            5    Jakarta
# 7          C8            6  Tangerang

# %%
#negative of criteria

# %%
df
# Out:
#   customer_id  item_bought       city
# 0          C1            5    Jakarta
# 1          C2            7  Tangerang
# 2          C3            2      Bogor
# 3          C4            4    Jakarta
# 4          C5            5  Tangerang
# 5          C6            2      Bogor
# 6          C7            5    Jakarta
# 7          C8            6  Tangerang
# 8          C9            1      Bogor
# 9         C10            2      Bogor

# %%
df[(df["item_bought"] > 5)]
# Out:
#   customer_id  item_bought       city
# 1          C2            7  Tangerang
# 7          C8            6  Tangerang

# %%
df[~(df["item_bought"] > 5)]
# Out:
#   customer_id  item_bought       city
# 0          C1            5    Jakarta
# 2          C3            2      Bogor
# 3          C4            4    Jakarta
# 4          C5            5  Tangerang
# 5          C6            2      Bogor
# 6          C7            5    Jakarta
# 8          C9            1      Bogor
# 9         C10            2      Bogor

# %%
#filter dataframe with several criteria(AND)

# %%
df
# Out:
#   customer_id  item_bought       city
# 0          C1            5    Jakarta
# 1          C2            7  Tangerang
# 2          C3            2      Bogor
# 3          C4            4    Jakarta
# 4          C5            5  Tangerang
# 5          C6            2      Bogor
# 6          C7            5    Jakarta
# 7          C8            6  Tangerang
# 8          C9            1      Bogor
# 9         C10            2      Bogor

# %%
df[(df["item_bought"] > 5) & (df["city"] != "Tangerang")]
# Out:
#   customer_id  item_bought  city
# 7          C8            6  Jawa

# %%
df[~(df["item_bought"] > 5) & (df["city"] != "Tangerang")]
# Out:
#   customer_id  item_bought     city
# 0          C1            5  Jakarta
# 2          C3            2    Bogor
# 3          C4            4  Jakarta
# 5          C6            2    Bogor
# 6          C7            5  Jakarta
# 8          C9            1    Bogor
# 9         C10            2    Bogor

# %%
df[(df["item_bought"]) > 7 | (df["city"] != "Bogor")]
# Out:
#   customer_id  item_bought       city
# 0          C1            5    Jakarta
# 1          C2            7  Tangerang
# 2          C3            2      Bogor
# 3          C4            4    Jakarta
# 4          C5            5  Tangerang
# 5          C6            2      Bogor
# 6          C7            5    Jakarta
# 7          C8            6       Jawa
# 9         C10            2      Bogor

# %%
df[~(df["item_bought"]) > 4 | (df["city"] != "Jakarta")]
# Out:
# Empty DataFrame
# Columns: [customer_id, item_bought, city]
# Index: []

# %%
#filter with isin operation

# %%
list_of_cities = ["Jakarta", "Tangerang", "Depok"]

# %%
df[(df["city"].isin(list_of_cities))]
# Out:
#   customer_id  item_bought       city
# 0          C1            5    Jakarta
# 1          C2            7  Tangerang
# 3          C4            4    Jakarta
# 4          C5            5  Tangerang
# 6          C7            5    Jakarta

# %%
list_of_cust = ["C5", "C1", "C7"]

# %%
df[(df["customer_id"].isin(list_of_cust))]
# Out:
#   customer_id  item_bought       city
# 0          C1            5    Jakarta
# 4          C5            5  Tangerang
# 6          C7            5    Jakarta

# %%
#Case Study

# %%
customers = pd.DataFrame({
    "id": [1,2,3,4],
    "name": ["Joko", "Udin", "Ilham", "Sam"]
})

# %%
orders = pd.DataFrame({
    "id": [1,2],
    "customer_id": [3,1]
})

# %%
customers
# Out:
#    id   name
# 0   1   Joko
# 1   2   Udin
# 2   3  Ilham
# 3   4    Sam

# %%
orders
# Out:
#    id  customer_id
# 0   1            3
# 1   2            1

# %%
id_order_list = list(orders["customer_id"])

# %%
id_order_list
# Out:
# [3, 1]

# %%
customers[(customers["id"].isin(id_order_list))]
# Out:
#    id   name
# 0   1   Joko
# 2   3  Ilham

# %%
df_customer_not_order = customers[~(customers["id"].isin(id_order_list))].sort_values(by = "name", ascending = True).reset_index(drop = True)

# %%
df_customer_not_order
# Out:
#    id  name
# 0   4   Sam
# 1   2  Udin

# %%
df_customer_not_order["name"]
# Out:
# 0     Sam
# 1    Udin
# Name: name, dtype: object

# %%
list_name =list(df_customer_not_order["name"])

# %%
list_name
# Out:
# ['Sam', 'Udin']

# %%
result = pd.DataFrame({
    'inactive_cust': list_name
})

# %%
result
# Out:
#   inactive_cust
# 0           Sam
# 1          Udin

# %%
#data_agregation

# %%
iris = pd.read_csv("https://gist.githubusercontent.com/thomasnield/03cf7c08016b514086ac8a9fdc07cc65/raw/bf4bb9d96e44bd8e7fbac3df6a2d779f439b3dc5/iris.csv")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#value counts

# %%
iris["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
iris["petal_length"].value_counts()
# Out:
# petal_length
# 1.5    14
# 1.4    12
# 5.1     8
# 4.5     8
# 1.6     7
# 1.3     7
# 5.6     6
# 4.7     5
# 4.9     5
# 4.0     5
# 4.2     4
# 5.0     4
# 4.4     4
# 4.8     4
# 1.7     4
# 3.9     3
# 4.6     3
# 5.7     3
# 4.1     3
# 5.5     3
# 6.1     3
# 5.8     3
# 3.3     2
# 5.4     2
# 6.7     2
# 5.3     2
# 5.9     2
# 6.0     2
# 1.2     2
# 4.3     2
# 1.9     2
# 3.5     2
# 5.2     2
# 3.0     1
# 1.1     1
# 3.7     1
# 3.8     1
# 6.6     1
# 6.3     1
# 1.0     1
# 6.9     1
# 3.6     1
# 6.4     1
# Name: count, dtype: int64

# %%
#group by, agregation

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.groupby(["species"]).count()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %%
iris.groupby(["species"]).min()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               4.3          2.3           1.0          0.1
# versicolor           4.9          2.0           3.0          1.0
# virginica            4.9          2.2           4.5          1.4

# %%
iris.groupby(["species"]).max()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.8          4.4           1.9          0.6
# versicolor           7.0          3.4           5.1          1.8
# virginica            7.9          3.8           6.9          2.5

# %%
iris.groupby(["species"]).sum()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             250.3        170.9          73.2         12.2
# versicolor         296.8        138.5         213.0         66.3
# virginica          329.4        148.7         277.6        101.3

# %%
iris.groupby(["species"]).mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
iris.groupby(["species"]).median()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.0          3.4          1.50          0.2
# versicolor           5.9          2.8          4.35          1.3
# virginica            6.5          3.0          5.55          2.0

# %%
iris.groupby(["species"]).describe()
# Out:
#            sepal_length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# species
# setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal_width         ... petal_length      petal_width         \
#                  count   mean  ...          75%  max       count   mean
# species                        ...
# setosa            50.0  3.418  ...        1.575  1.9        50.0  0.244
# versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# species
# setosa      0.107210  0.1  0.2  0.2  0.3  0.6
# versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# ...

# %%
iris.groupby(["species"]).describe().T
# Out:
# species                setosa  versicolor  virginica
# sepal_length count  50.000000   50.000000  50.000000
#              mean    5.006000    5.936000   6.588000
#              std     0.352490    0.516171   0.635880
#              min     4.300000    4.900000   4.900000
#              25%     4.800000    5.600000   6.225000
#              50%     5.000000    5.900000   6.500000
#              75%     5.200000    6.300000   6.900000
#              max     5.800000    7.000000   7.900000
# sepal_width  count  50.000000   50.000000  50.000000
#              mean    3.418000    2.770000   2.974000
#              std     0.381024    0.313798   0.322497
#              min     2.300000    2.000000   2.200000
#              25%     3.125000    2.525000   2.800000
#              50%     3.400000    2.800000   3.000000
#              75%     3.675000    3.000000   3.175000
#              max     4.400000    3.400000   3.800000
# petal_length count  50.000000   50.000000  50.000000
# ...

# %%
df = iris.groupby(["species"]).mean().reset_index()
df
# Out:
#       species  sepal_length  sepal_width  petal_length  petal_width
# 0      setosa         5.006        3.418         1.464        0.244
# 1  versicolor         5.936        2.770         4.260        1.326
# 2   virginica         6.588        2.974         5.552        2.026

# %%
df[(df["species"] == "setosa")]
# Out:
#   species  sepal_length  sepal_width  petal_length  petal_width
# 0  setosa         5.006        3.418         1.464        0.244

# %%
iris.groupby(["species"]).agg(["min", "max"])
# Out:
#            sepal_length      sepal_width      petal_length      petal_width  \
#                     min  max         min  max          min  max         min
# species
# setosa              4.3  5.8         2.3  4.4          1.0  1.9         0.1
# versicolor          4.9  7.0         2.0  3.4          3.0  5.1         1.0
# virginica           4.9  7.9         2.2  3.8          4.5  6.9         1.4
#
#
#             max
# species
# setosa      0.6
# versicolor  1.8
# virginica   2.5

# %%
iris.groupby(["species"]).agg({"sepal_length": ["min", "sum"], "sepal_width": ["max", "mean"]})
# Out:
#            sepal_length        sepal_width
#                     min    sum         max   mean
# species
# setosa              4.3  250.3         4.4  3.418
# versicolor          4.9  296.8         3.4  2.770
# virginica           4.9  329.4         3.8  2.974

# %%
#data merging

# %%
df1 = pd.DataFrame({
    "cust_id": ["C1", "C2", "C3", "C4", "C5"],
    "item_bought": [10,15,20,35,4],
    "city": ["Bandung", "Bali", "Jakarta", "Bogor", "Tangerang"]
})
df1
# Out:
#   cust_id  item_bought       city
# 0      C1           10    Bandung
# 1      C2           15       Bali
# 2      C3           20    Jakarta
# 3      C4           35      Bogor
# 4      C5            4  Tangerang

# %%
df3 = pd.DataFrame({
    "cust_no": ["C1", "C2", "C3", "C5", "C6", "C7", "C8"],
    "age": [24,31,23,40,35,28,34]
})
df3
# Out:
#   cust_no  age
# 0      C1   24
# 1      C2   31
# 2      C3   23
# 3      C5   40
# 4      C6   35
# 5      C7   28
# 6      C8   34

# %%
df1.merge(df3, how = "left", left_on = "cust_id", right_on = "cust_no")
# Out:
#   cust_id  item_bought       city cust_no   age
# 0      C1           10    Bandung      C1  24.0
# 1      C2           15       Bali      C2  31.0
# 2      C3           20    Jakarta      C3  23.0
# 3      C4           35      Bogor     NaN   NaN
# 4      C5            4  Tangerang      C5  40.0

# %%
df1.merge(df3, how = "right", left_on = "cust_id", right_on = "cust_no")
# Out:
#   cust_id  item_bought       city cust_no  age
# 0      C1         10.0    Bandung      C1   24
# 1      C2         15.0       Bali      C2   31
# 2      C3         20.0    Jakarta      C3   23
# 3      C5          4.0  Tangerang      C5   40
# 4     NaN          NaN        NaN      C6   35
# 5     NaN          NaN        NaN      C7   28
# 6     NaN          NaN        NaN      C8   34

# %%
df3.merge(df1, how = "right", left_on = "cust_no", right_on = "cust_id")
# Out:
#   cust_no   age cust_id  item_bought       city
# 0      C1  24.0      C1           10    Bandung
# 1      C2  31.0      C2           15       Bali
# 2      C3  23.0      C3           20    Jakarta
# 3     NaN   NaN      C4           35      Bogor
# 4      C5  40.0      C5            4  Tangerang

# %%
df1.merge(df3, how = "inner", left_on = "cust_id", right_on = "cust_no")
# Out:
#   cust_id  item_bought       city cust_no  age
# 0      C1           10    Bandung      C1   24
# 1      C2           15       Bali      C2   31
# 2      C3           20    Jakarta      C3   23
# 3      C5            4  Tangerang      C5   40

# %%
df1.merge(df3, how = "outer", left_on = "cust_id", right_on = "cust_no")
# Out:
#   cust_id  item_bought       city cust_no   age
# 0      C1         10.0    Bandung      C1  24.0
# 1      C2         15.0       Bali      C2  31.0
# 2      C3         20.0    Jakarta      C3  23.0
# 3      C4         35.0      Bogor     NaN   NaN
# 4      C5          4.0  Tangerang      C5  40.0
# 5     NaN          NaN        NaN      C6  35.0
# 6     NaN          NaN        NaN      C7  28.0
# 7     NaN          NaN        NaN      C8  34.0

# %%
df1.merge(df3, how = "inner", left_on = "cust_id", right_on = "cust_no").drop(columns = ["cust_no"])
# Out:
#   cust_id  item_bought       city  age
# 0      C1           10    Bandung   24
# 1      C2           15       Bali   31
# 2      C3           20    Jakarta   23
# 3      C5            4  Tangerang   40
